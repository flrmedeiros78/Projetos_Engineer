# %%
print("Olá Mundo")

# %%
print(5/2)
print(5//2)

# %%
nome = "Fabio"
idade = 47
altura = 1.75
soma = (1*2/2)+3
print(f"Olá {nome}, sua idade é {idade} altura {altura} e a soma é {soma}\n")

preco = 100
desconto  = 10
preco_final = preco - desconto
print(preco_final)

# %%
print(type(nome))
print(type(idade))
print(type(altura))

# %%
mensagem = 'python é Incrivel'
print(mensagem)
print(type(mensagem))
print(mensagem.lower())
print(mensagem.upper())
print(mensagem.title())
print(mensagem.capitalize())
print(mensagem.swapcase())
print(mensagem.replace('python','java').upper())
print(mensagem.replace('python','java').lower())
print(len(mensagem))

# %% [markdown]
# Fluxo de Controle

# %%
idade = int(input("qual sua idade ?"))

# %%
if int(idade) >= 18 :
    print("Pode Dirigir")
else:
    print("Não pode Dirigir")

# %%
# !pip install pandas

# %%
dbutils.library.restartPython()

# %% [markdown]
# # Trabalhando com Bibliotecas

# %%
import pandas as pd
